# %% [markdown]
# <a href="https://colab.research.google.com/github/aminejarraya/Deep-Learning-Image-Compression-/blob/main/Collect_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Download Necessary Packages

# %%
#Install open slide Package
# !apt update && apt install -y openslide-tools
# !pip install openslide-python
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:4 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu bionic InRelease
# Ign:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:10 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [450 kB]
# Get:11 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,414 kB]
# ...

# %%
#Packages to Unzip rar file
# !pip install pyunpack
# !pip install patool
# Out:
# ...
#      |████████████████████████████████| 81kB 9.7MB/s
# ...

# %% [markdown]
# ## Import packages

# %%
import cv2
from google.colab import drive
import numpy as np
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Conv2DTranspose
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Reshape
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
import tensorflow
from pyunpack import Archive
import openslide
import numpy as np
from google.colab.patches import cv2_imshow
from tqdm import tqdm

# %%
#Mount Drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
#Extract zip file located in the drive into home
Archive('/content/drive/MyDrive/TCGA-A8-A08F-01A-01-TS1.e2b24767-1df7-431b-bba2-45d1b4e767d8.rar').extractall('./')

# %% [markdown]
# ## Read svs/tif/tiff file

# %%
slide = openslide.OpenSlide("TCGA.svs")
slide2 = openslide.OpenSlide("/content/drive/MyDrive/Pathology/CMU-1.svs")
slide3 = openslide.OpenSlide("/content/drive/MyDrive/Pathology/CMU-2.svs")
slide4 = openslide.OpenSlide("/content/drive/MyDrive/Pathology/CMU-3.svs")
slide5 = openslide.OpenSlide("/content/drive/MyDrive/TT.svs")

# %% [markdown]
# #Collect Data from 5 Slides

# %%
index = 0
for i in tqdm(range(12507,17584,256)):
    for j in tqdm(range(19493,20975,256)):
        x = slide.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.tif',x)
        index = index +1


for i in tqdm(range(7010,21475,256)):
    for j in tqdm(range(17132,29674,256)):
        x = slide.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.tif',x)
        index = index +1

for i in tqdm(range(21475,29674,256)):
    for j in tqdm(range(7010,17132,256)):
        x = slide.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.tif',x)
        index = index +1  

for i in tqdm(range(21904,28257,256)):
    for j in tqdm(range(39519,49557,256)):
        x = slide.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.tif',x)
        index = index +1

for i in tqdm(range(29274,31863,256)):
    for j in tqdm(range(37695,44538,256)):
        x = slide.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.tif',x)
        index = index +1    

for i in tqdm(range(7010,17584,256)):
    for j in tqdm(range(19493,20975,256)):
        x = slide.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.tif',x)
        index = index +1

for i in tqdm(range(18708,21176,256)):
    for j in tqdm(range(47291,52394,256)):
        x = slide.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.tif',x)
        index = index +1  

for i in tqdm(range(14210,17611,256)):
    for j in tqdm(range(52315,54015,256)):
        x = slide.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.tif',x)
        index = index +1

for i in tqdm(range(17668,18147,256)):
    for j in tqdm(range(52637,53465,256)):
        x = slide.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.tif',x)
        index = index +1

for i in tqdm(range(6920,10446,256)):
    for j in tqdm(range(46970,50286,256)):
        x = slide.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.tif',x)
        index = index +1

#Slide 2 

for i in tqdm(range(4968,14987,256)):
    for j in tqdm(range(8491,16138,256)):
        x = slide2.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.tif',x)
        index = index +1  

for i in tqdm(range(2726,4760,256)):
    for j in tqdm(range(4230,16511,256)):
        x = slide2.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.tif',x)
        index = index +1

for i in tqdm(range(21475,29674,256)):
    for j in tqdm(range(7010,17132,256)):
        x = slide2.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.tif',x)
        index = index +1    

for i in tqdm(range(4886,7504,256)):
    for j in tqdm(range(5909,8395,256)):
        x = slide2.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.tif',x)
        index = index +1

for i in tqdm(range(4795,8850,256)):
    for j in tqdm(range(16277,18622,256)):
        x = slide2.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.tif',x)
        index = index +1  

for i in tqdm(range(16474,23350,256)):
    for j in tqdm(range(88722,103244,256)):
        x = slide2.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.tif',x)
        index = index +1

for i in tqdm(range(14479,16281,256)):
    for j in tqdm(range(91324,102626,256)):
        x = slide2.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.tif',x)
        index = index +1    

for i in tqdm(range(102594,14362,256)):
    for j in tqdm(range(99896,20975,256)):
        x = slide2.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.tif',x)
        index = index +1

#Slide 3

for i in tqdm(range(5316,12653,256)):
    for j in tqdm(range(5357,18149,256)):
        x = slide3.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.tif',x)
        index = index +1  

for i in tqdm(range(2090,8790,256)):
    for j in tqdm(range(18149,25250,256)):
        x = slide3.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.tif',x)
        index = index +1

for i in tqdm(range(13691,17989,256)):
    for j in tqdm(range(6539,31781,256)):
        x = slide3.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.tif',x)
        index = index +1    

for i in tqdm(range(18478,22512,256)):
    for j in tqdm(range(7863,28868,256)):
        x = slide3.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.tif',x)
        index = index +1

for i in tqdm(range(7518,9555,256)):
    for j in tqdm(range(50666,67922,256)):
        x = slide3.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.tif',x)
        index = index +1  

#slide4 4

for i in tqdm(range(19119,23022,256)):
    for j in tqdm(range(3854,10029,256)):
        x = slide4.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.tif',x)
        index = index +1

for i in tqdm(range(23467,33496,256)):
    for j in tqdm(range(2866,12154,256)):
        x = slide4.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.tif',x)
        index = index +1

for i in tqdm(range(28160,33051,256)):
    for j in tqdm(range(12747,19317,256)):
        x = slide4.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.tif',x)
        index = index +1

for i in tqdm(range(33446,42389,256)):
    for j in tqdm(range(10523,20848,256)):
        x = slide4.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.tif',x)
        index = index +1  

for i in tqdm(range(11610,29692,256)):
    for j in tqdm(range(54443,65559,256)):
        x = slide4.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.tif',x)
        index = index +1

for i in tqdm(range(8201,19712,256)):
    for j in tqdm(range(43525,53406,256)):
        x = slide4.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.tif',x)
        index = index +1    

#Slide 5 
for i in tqdm(range(21606,28021,256)):
    for j in tqdm(range(2164,8513,256)):
        x = slide5.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.tif',x)
        index = index +1

for i in tqdm(range(17671,21320,256)):
    for j in tqdm(range(4531,11137,256)):
        x = slide5.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.tif',x)
        index = index +1  

for i in tqdm(range(13617,16693,256)):
    for j in tqdm(range(9563,15238,256)):
        x = slide5.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.tif',x)
        index = index +1

for i in tqdm(range(20246,23680,256)):
    for j in tqdm(range(15930,21105,256)):
        x = slide5.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.tif',x)
        index = index +1

# %%
#Mount Drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
#Extract zip file located in the drive into home
Archive('/content/drive/MyDrive/TCGA-A8-A08F-01A-01-TS1.e2b24767-1df7-431b-bba2-45d1b4e767d8.rar').extractall('./')

# %%
slide = openslide.OpenSlide("TCGA.svs")
slide5 = openslide.OpenSlide("/content/drive/MyDrive/TT.svs")

# %% [markdown]
# #Slide 1

# %%
index = 0
for i in tqdm(range(12507,17584,256)):
    for j in tqdm(range(19493,20975,256)):
        x = slide.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.png',x)
        index = index +1


for i in tqdm(range(7010,21475,256)):
    for j in tqdm(range(17132,29674,256)):
        x = slide.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.png',x)
        index = index +1

for i in tqdm(range(21475,29674,256)):
    for j in tqdm(range(7010,17132,256)):
        x = slide.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.png',x)
        index = index +1  

for i in tqdm(range(21904,28257,256)):
    for j in tqdm(range(39519,49557,256)):
        x = slide.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.png',x)
        index = index +1

for i in tqdm(range(29274,31863,256)):
    for j in tqdm(range(37695,44538,256)):
        x = slide.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.png',x)
        index = index +1    

for i in tqdm(range(7010,17584,256)):
    for j in tqdm(range(19493,20975,256)):
        x = slide.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.png',x)
        index = index +1

for i in tqdm(range(18708,21176,256)):
    for j in tqdm(range(47291,52394,256)):
        x = slide.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.png',x)
        index = index +1  

for i in tqdm(range(14210,17611,256)):
    for j in tqdm(range(52315,54015,256)):
        x = slide.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.png',x)
        index = index +1

for i in tqdm(range(17668,18147,256)):
    for j in tqdm(range(52637,53465,256)):
        x = slide.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.png',x)
        index = index +1

for i in tqdm(range(6920,10446,256)):
    for j in tqdm(range(46970,50286,256)):
        x = slide.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.png',x)
        index = index +1
# Out:
# ...
# 100%|██████████| 6/6 [00:00<00:00, 97.90it/s]
#
# ...
# 100%|██████████| 6/6 [00:00<00:00, 71.93it/s]
#
# ...
# 100%|██████████| 6/6 [00:00<00:00, 93.59it/s]
#
# ...
# 100%|██████████| 6/6 [00:00<00:00, 75.02it/s]
#
# ...
# 100%|██████████| 6/6 [00:00<00:00, 96.54it/s]
#
# ...
# 100%|██████████| 6/6 [00:00<00:00, 93.02it/s]
#
# ...
# 100%|██████████| 6/6 [00:00<00:00, 73.79it/s]
#
# ...
# 100%|██████████| 6/6 [00:00<00:00, 96.26it/s]
#
# ...
# 100%|██████████| 6/6 [00:00<00:00, 98.08it/s]
#
# ...
# 100%|██████████| 6/6 [00:00<00:00, 103.82it/s]
#
# ...
# 100%|██████████| 6/6 [00:00<00:00, 109.71it/s]
#
# ...
# 100%|██████████| 6/6 [00:00<00:00, 160.14it/s]
#
# ...
# 100%|██████████| 6/6 [00:00<00:00, 146.68it/s]
#
# 100%|██████████| 6/6 [00:00<00:00, 156.03it/s]
#
# ...
# 100%|██████████| 6/6 [00:00<00:00, 115.91it/s]
#
# ...
# 100%|██████████| 6/6 [00:00<00:00, 90.09it/s]
#
# ...
# 100%|██████████| 6/6 [00:00<00:00, 123.46it/s]
#
# ...
# 100%|██████████| 6/6 [00:00<00:00, 107.33it/s]
#
# ...
# 100%|██████████| 6/6 [00:00<00:00, 78.64it/s]
#
# ...

# %% [markdown]
# #Slide 2

# %%
for i in tqdm(range(10473,24460,256)):
    for j in tqdm(range(87479,102688,256)):
        x = slide5.read_region((j,i),0,(256,256))
        x = np.array(x)
        cv2.imwrite("/content/drive/MyDrive/Traine/Train/"+str(index)+'.png',x)
        index = index +1
# Out:
# ...
# 100%|██████████| 55/55 [00:35<00:00,  1.53it/s]

# %%
import os
for i in range(15491):
  if not os.path.exists('/content/drive/MyDrive/Traine/Train/'+str(i)+'.png'):
    continue
  if os.stat('/content/drive/MyDrive/Traine/Train/'+str(i)+'.png').st_size < 60000:
    os.remove('/content/drive/MyDrive/Traine/Train/'+str(i)+'.png')

# %%
from google.colab import auth
auth.authenticate_user()

project_id = 'azinfolab'
# !gcloud config set project {project_id}
# !gsutil ls
# Out:
# Updated property [core/project].
# gs://azinfo_bucket/
# gs://azinfolab.appspot.com/
# gs://gcf-sources-692015800051-us-central1/
# gs://staging.azinfolab.appspot.com/
# gs://tiled/
# gs://us.artifacts.azinfolab.appspot.com/

# %%
bucket_name = 'tiled'

# !gsutil -m cp -r /content/drive/MyDrive/Traine/Train/* gs://{bucket_name}/Traine/Train
# Out:
# Streaming output truncated to the last 5000 lines.
# Copying file:///content/drive/MyDrive/Traine/Train/2286.png [Content-Type=image/png]...
# Copying file:///content/drive/MyDrive/Traine/Train/2287.png [Content-Type=image/png]...
# Copying file:///content/drive/MyDrive/Traine/Train/2288.png [Content-Type=image/png]...
# Copying file:///content/drive/MyDrive/Traine/Train/22.png [Content-Type=image/png]...
# Copying file:///content/drive/MyDrive/Traine/Train/2325.png [Content-Type=image/png]...
# Copying file:///content/drive/MyDrive/Traine/Train/2326.png [Content-Type=image/png]...
# Copying file:///content/drive/MyDrive/Traine/Train/2327.png [Content-Type=image/png]...
# Copying file:///content/drive/MyDrive/Traine/Train/2328.png [Content-Type=image/png]...
# Copying file:///content/drive/MyDrive/Traine/Train/2329.png [Content-Type=image/png]...
# Copying file:///content/drive/MyDrive/Traine/Train/2330.png [Content-Type=image/png]...
# ...

# %% [markdown]
# # Train and Test Split

# %%
path = "/content/drive/MyDrive/Traine/Train"
dirs = os.listdir(path)
train = len(dirs) * 0.2
test = len(dirs) * 0.8

# %%
cd /content/drive/MyDrive/Traine/Train
# Out:
# /content/drive/MyDrive/Traine/Train

# %%
# !bash -c 'mv {0..6748}.tif /content/drive/MyDrive/Vale/Val'
